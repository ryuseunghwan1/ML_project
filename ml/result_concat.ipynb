# %%
borderline_classweight = pd.read_csv('result/borderlineSMOTE_classweight_result.csv', index_col=0)
borderline_no_classweight = pd.read_csv('result/borderlineSMOTE_result.csv', index_col=0)
smote_adasyn_classweight = pd.read_csv('result/SMOTE_and_ADASYN_classweight_result.csv', index_col=0)
smote_adasyn_no_classweight = pd.read_csv('result/SVMSMOTE_ROS_results.csv', index_col=0)
svmsmote_ros_classweight = pd.read_csv('result/SVMSMOTE_ROS_classweight_result.csv', index_col=0)
svmsmote_ros_no_classweight = pd.read_csv('result/SVMSMOTE_ROS_results.csv', index_col=0)

# %% [markdown]
# ## 1) borderline_classweight

# %%
print(borderline_classweight.shape)
borderline_classweight.head(1)
# Out:
# (80, 16)
#    class_weight  null_del  encoded scaler   sampler   classifier  \
# 0             1         1        1   None  BdlSMOTE  LogisticReg
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.843135         0.761502      0.999219  0.864313   0.843135
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.614226         0.00332     0.571429  0.006601  0.592875

# %%
borderline_classweight_cp = borderline_classweight.copy()
borderline_classweight_cp.drop("class_weight", axis=1, inplace=True)
borderline_classweight_cp["class_weight_YN"] = 1
borderline_classweight_cp.head(1)
# Out:
#    null_del  encoded scaler   sampler   classifier  train accuracy  \
# 0         1        1   None  BdlSMOTE  LogisticReg        0.843135
#
#    train precision  train recall  train f1  train auc  test accuracy  \
# 0         0.761502      0.999219  0.864313   0.843135       0.614226
#
#    test precision  test recall   test f1  test auc  class_weight_YN
# 0         0.00332     0.571429  0.006601  0.592875                1

# %%
borderline_classweight_cp.columns
# Out:
# Index(['null_del', 'encoded', 'scaler', 'sampler', 'classifier',
#        'train accuracy', 'train precision', 'train recall', 'train f1',
#        'train auc', 'test accuracy', 'test precision', 'test recall',
#        'test f1', 'test auc', 'class_weight_YN'],
#       dtype='object')

# %%
borderline_classweight_cp = borderline_classweight_cp[['class_weight_YN', 'null_del', 'encoded', 'scaler', 'sampler', 'classifier',
                                                       'train accuracy', 'train precision', 'train recall', 'train f1', 'train auc',
                                                       'test accuracy', 'test precision', 'test recall', 'test f1', 'test auc']]

# %%
print(borderline_classweight_cp.shape)
borderline_classweight_cp.head(2)
# Out:
# (80, 16)
#    class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 0                1         1        1   None  BdlSMOTE   LogisticReg
# 1                1         1        1   None  BdlSMOTE  DecisionTree
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.843135         0.761502      0.999219  0.864313   0.843135
# 1        0.786239         0.700844      0.998828  0.823715   0.786239
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.614226        0.003320     0.571429  0.006601  0.592875
# 1       0.579622        0.002288     0.428571  0.004552  0.504266

# %% [markdown]
# ## 2) borderilne_no_classweight

# %%
print(borderline_no_classweight.shape)
borderline_no_classweight.head(1)
# Out:
# (80, 15)
#    null_del  encoded scaler   sampler   classifier  train accuracy  \
# 0         1        1   None  BdlSMOTE  LogisticReg        0.998672
#
#    train precision  train recall  train f1  train auc  test accuracy  \
# 0              1.0      0.997345  0.998671   0.998672       0.997437
#
#    test precision  test recall  test f1  test auc
# 0             0.0          0.0      0.0  0.499839

# %%
borderline_no_classweight_cp = borderline_no_classweight.copy()
borderline_no_classweight_cp["class_weight_YN"] = 0
borderline_no_classweight_cp.head(3)
# Out:
#    null_del  encoded scaler   sampler    classifier  train accuracy  \
# 0         1        1   None  BdlSMOTE   LogisticReg        0.998672
# 1         1        1   None  BdlSMOTE  DecisionTree        0.864456
# 2         1        1   None  BdlSMOTE  RandomForest        0.813574
#
#    train precision  train recall  train f1  train auc  test accuracy  \
# 0         1.000000      0.997345  0.998671   0.998672       0.997437
# 1         0.787612      0.998047  0.880430   0.864456       0.710990
# 2         0.728723      0.999063  0.842743   0.813574       0.442807
#
#    test precision  test recall   test f1  test auc  class_weight_YN
# 0         0.00000     0.000000  0.000000  0.499839                0
# 1         0.00333     0.428571  0.006608  0.570098                0
# 2         0.00344     0.857143  0.006853  0.649509                0

# %%
borderline_no_classweight_cp = borderline_no_classweight_cp[['class_weight_YN', 'null_del', 'encoded', 'scaler', 'sampler', 'classifier',
                                                       'train accuracy', 'train precision', 'train recall', 'train f1', 'train auc',
                                                       'test accuracy', 'test precision', 'test recall', 'test f1', 'test auc']]

# %%
print(borderline_no_classweight_cp.shape)
borderline_classweight_cp.head(2)
# Out:
# (80, 16)
#    class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 0                1         1        1   None  BdlSMOTE   LogisticReg
# 1                1         1        1   None  BdlSMOTE  DecisionTree
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.843135         0.761502      0.999219  0.864313   0.843135
# 1        0.786239         0.700844      0.998828  0.823715   0.786239
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.614226        0.003320     0.571429  0.006601  0.592875
# 1       0.579622        0.002288     0.428571  0.004552  0.504266

# %% [markdown]
# ## 3) smote_adasyn_classweight

# %%
print(smote_adasyn_classweight.shape)
smote_adasyn_classweight.head(1)
# Out:
# (160, 15)
#               null_del  encoded scaler sampler   classifier  train accuracy  \
# class_weight
# 1                    0        0   None   SMOTE  LogisticReg        0.500156
#
#               train precision  train recall  train f1  train auc  \
# class_weight
# 1                    0.500078           1.0  0.666736   0.500156
#
#               test accuracy  test precision  test recall   test f1  test auc
# class_weight
# 1                  0.002563        0.002244          1.0  0.004477  0.500161

# %%
smote_adasyn_classweight_cp = smote_adasyn_classweight.copy()

# %%
smote_adasyn_classweight_cp.reset_index(inplace=True)
smote_adasyn_classweight_cp.rename(columns={"class_weight": "class_weight_YN"}, inplace=True)
smote_adasyn_classweight_cp.head(1)
# Out:
#    class_weight_YN  null_del  encoded scaler sampler   classifier  \
# 0                1         0        0   None   SMOTE  LogisticReg
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.500156         0.500078           1.0  0.666736   0.500156
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.002563        0.002244          1.0  0.004477  0.500161

# %%
smote_adasyn_classweight_cp = smote_adasyn_classweight_cp[['class_weight_YN', 'null_del', 'encoded', 'scaler', 'sampler', 'classifier',
                                                       'train accuracy', 'train precision', 'train recall', 'train f1', 'train auc',
                                                       'test accuracy', 'test precision', 'test recall', 'test f1', 'test auc']]

# %%
print(smote_adasyn_classweight_cp.shape)
smote_adasyn_classweight_cp.head(2)
# Out:
# (160, 16)
#    class_weight_YN  null_del  encoded scaler sampler    classifier  \
# 0                1         0        0   None   SMOTE   LogisticReg
# 1                1         0        0   None   SMOTE  DecisionTree
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.500156         0.500078      1.000000  0.666736   0.500156
# 1        0.580405         0.543721      0.999922  0.704410   0.580405
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.002563        0.002244     1.000000  0.004477  0.500161
# 1       0.159564        0.002283     0.857143  0.004554  0.507570

# %% [markdown]
# ## 4) smote_adasyn_no_classweight

# %%
print(smote_adasyn_no_classweight.shape)
smote_adasyn_no_classweight.head(1)
# Out:
# (160, 14)
#              train accuracy  train precision  train recall  train f1  \
# classifier
# LogisticReg        0.774697         0.553007      0.995547  0.711044
#
#              train auc  test accuracy  test precision  test recall   test f1  \
# classifier
# LogisticReg    0.84251       0.684396        0.006061     0.857143  0.012036
#
#              test auc  null_del  encoded scaler   sampler
# classifier
# LogisticReg  0.770575       0.0      0.0   None  SVMSMOTE

# %%
smote_adasyn_no_classweight_cp = smote_adasyn_no_classweight.copy()
smote_adasyn_no_classweight_cp.reset_index(inplace=True)
smote_adasyn_no_classweight_cp["class_weight_YN"] = 0
smote_adasyn_no_classweight_cp.head(1)
# Out:
#     classifier  train accuracy  train precision  train recall  train f1  \
# 0  LogisticReg        0.774697         0.553007      0.995547  0.711044
#
#    train auc  test accuracy  test precision  test recall   test f1  test auc  \
# 0    0.84251       0.684396        0.006061     0.857143  0.012036  0.770575
#
#    null_del  encoded scaler   sampler  class_weight_YN
# 0       0.0      0.0   None  SVMSMOTE                0

# %%
smote_adasyn_no_classweight_cp = smote_adasyn_no_classweight_cp[['class_weight_YN', 'null_del', 'encoded', 'scaler', 'sampler', 'classifier',
                                                       'train accuracy', 'train precision', 'train recall', 'train f1', 'train auc',
                                                       'test accuracy', 'test precision', 'test recall', 'test f1', 'test auc']]

# %%
print(smote_adasyn_no_classweight_cp.shape)
smote_adasyn_no_classweight_cp.head(2)
# Out:
# (160, 16)
#    class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 0                0       0.0      0.0   None  SVMSMOTE   LogisticReg
# 1                0       0.0      0.0   None  SVMSMOTE  DecisionTree
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.774697         0.553007      0.995547  0.711044   0.842510
# 1        0.936489         0.816988      0.994738  0.897143   0.954375
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.684396        0.006061     0.857143  0.012036  0.770575
# 1       0.867350        0.004866     0.285714  0.009569  0.577186

# %% [markdown]
# ## 5) svmsmote_ros_classweight

# %%
print(svmsmote_ros_classweight.shape)
svmsmote_ros_classweight.head(1)
# Out:
# (150, 15)
#              train accuracy  train precision  train recall  train f1  \
# classifier
# LogisticReg        0.364103         0.304409      0.998988  0.466629
#
#              train auc  test accuracy  test precision  test recall   test f1  \
# classifier
# LogisticReg   0.559046       0.132009        0.002577          1.0  0.005141
#
#              test auc  null_del  encoded scaler   sampler      class_weight
# classifier
# LogisticReg  0.565029         0        0   None  SVMSMOTE  {0: 0.005, 1: 1}

# %%
svmsmote_ros_classweight_cp = svmsmote_ros_classweight.copy()
svmsmote_ros_classweight_cp.reset_index(inplace=True)
svmsmote_ros_classweight_cp["class_weight_YN"] = 1
svmsmote_ros_classweight_cp.drop("class_weight", axis=1, inplace=True)
svmsmote_ros_classweight_cp.head(1)
# Out:
#     classifier  train accuracy  train precision  train recall  train f1  \
# 0  LogisticReg        0.364103         0.304409      0.998988  0.466629
#
#    train auc  test accuracy  test precision  test recall   test f1  test auc  \
# 0   0.559046       0.132009        0.002577          1.0  0.005141  0.565029
#
#    null_del  encoded scaler   sampler  class_weight_YN
# 0         0        0   None  SVMSMOTE                1

# %%
svmsmote_ros_classweight_cp = svmsmote_ros_classweight_cp[['class_weight_YN', 'null_del', 'encoded', 'scaler', 'sampler', 'classifier',
                                                       'train accuracy', 'train precision', 'train recall', 'train f1', 'train auc',
                                                       'test accuracy', 'test precision', 'test recall', 'test f1', 'test auc']]

# %%
print(svmsmote_ros_classweight_cp.shape)
svmsmote_ros_classweight_cp.head(2)
# Out:
# (150, 16)
#    class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 0                1         0        0   None  SVMSMOTE   LogisticReg
# 1                1         0        0   None  SVMSMOTE  DecisionTree
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.364103         0.304409      0.998988  0.466629   0.559046
# 1        0.888250         0.714534      0.996964  0.832446   0.921631
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.132009        0.002577     1.000000  0.005141  0.565029
# 1       0.793976        0.004673     0.428571  0.009245  0.611685

# %% [markdown]
# ## 6) svmsmote_ros_no_classweight

# %%
print(svmsmote_ros_no_classweight.shape)
svmsmote_ros_no_classweight.head(1)
# Out:
# (160, 14)
#              train accuracy  train precision  train recall  train f1  \
# classifier
# LogisticReg        0.774697         0.553007      0.995547  0.711044
#
#              train auc  test accuracy  test precision  test recall   test f1  \
# classifier
# LogisticReg    0.84251       0.684396        0.006061     0.857143  0.012036
#
#              test auc  null_del  encoded scaler   sampler
# classifier
# LogisticReg  0.770575       0.0      0.0   None  SVMSMOTE

# %%
svmsmote_ros_no_classweight_cp = svmsmote_ros_no_classweight.copy()
svmsmote_ros_no_classweight_cp.reset_index(inplace=True)
svmsmote_ros_no_classweight_cp["class_weight_YN"] = 0
svmsmote_ros_no_classweight_cp.head(1)
# Out:
#     classifier  train accuracy  train precision  train recall  train f1  \
# 0  LogisticReg        0.774697         0.553007      0.995547  0.711044
#
#    train auc  test accuracy  test precision  test recall   test f1  test auc  \
# 0    0.84251       0.684396        0.006061     0.857143  0.012036  0.770575
#
#    null_del  encoded scaler   sampler  class_weight_YN
# 0       0.0      0.0   None  SVMSMOTE                0

# %%
svmsmote_ros_no_classweight_cp = svmsmote_ros_no_classweight_cp[['class_weight_YN', 'null_del', 'encoded', 'scaler', 'sampler', 'classifier',
                                                       'train accuracy', 'train precision', 'train recall', 'train f1', 'train auc',
                                                       'test accuracy', 'test precision', 'test recall', 'test f1', 'test auc']]

# %%
print(svmsmote_ros_no_classweight_cp.shape)
svmsmote_ros_no_classweight_cp.head(2)
# Out:
# (160, 16)
#    class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 0                0       0.0      0.0   None  SVMSMOTE   LogisticReg
# 1                0       0.0      0.0   None  SVMSMOTE  DecisionTree
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.774697         0.553007      0.995547  0.711044   0.842510
# 1        0.936489         0.816988      0.994738  0.897143   0.954375
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.684396        0.006061     0.857143  0.012036  0.770575
# 1       0.867350        0.004866     0.285714  0.009569  0.577186

# %% [markdown]
# ## Concat

# %%
df_concat = pd.concat([borderline_classweight_cp, borderline_no_classweight_cp, svmsmote_ros_classweight_cp, 
                       svmsmote_ros_no_classweight_cp, smote_adasyn_classweight_cp, smote_adasyn_no_classweight_cp], axis=0)

# %%
print(df_concat.shape)
df_concat.head(3)
# Out:
# (790, 16)
#    class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 0                1       1.0      1.0   None  BdlSMOTE   LogisticReg
# 1                1       1.0      1.0   None  BdlSMOTE  DecisionTree
# 2                1       1.0      1.0   None  BdlSMOTE  RandomForest
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.843135         0.761502      0.999219  0.864313   0.843135
# 1        0.786239         0.700844      0.998828  0.823715   0.786239
# 2        0.896009         0.828209      0.999297  0.905745   0.896009
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.614226        0.003320     0.571429  0.006601  0.592875
# 1       0.579622        0.002288     0.428571  0.004552  0.504266
# 2       0.700096        0.004269     0.571429  0.008475  0.635907

# %%
df_concat.sort_values(by=["test recall", "test accuracy"], ascending=False, inplace=True)

# %%
df_concat[df_concat["test recall"] == 1].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#     class_weight_YN  null_del  encoded scaler   sampler   classifier  \
# 44                0       0.0      1.0   None  BdlSMOTE          SVC
# 64                0       0.0      0.0   None  BdlSMOTE          SVC
# 40                1       0.0      1.0   None  BdlSMOTE  LogisticReg
#
#     test accuracy  test recall
# 44       0.284204          1.0
# 64       0.284204          1.0
# 40       0.136815          1.0

# %%
df_concat[df_concat["test recall"] == 6/7].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#     class_weight_YN  null_del  encoded scaler   sampler   classifier  \
# 0                 0       0.0      0.0   None  SVMSMOTE  LogisticReg
# 0                 0       0.0      0.0   None  SVMSMOTE  LogisticReg
# 40                0       0.0      1.0   None  BdlSMOTE  LogisticReg
#
#     test accuracy  test recall
# 0        0.684396     0.857143
# 0        0.684396     0.857143
# 40       0.647228     0.857143

# %%
df_concat[df_concat["test recall"] == 5/7].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#     class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 42                1       1.0      0.0   None  SVMSMOTE  RandomForest
# 52                1       1.0      0.0     MM  SVMSMOTE  RandomForest
# 62                1       1.0      0.0     SD  SVMSMOTE  RandomForest
#
#     test accuracy  test recall
# 42       0.817687     0.714286
# 52       0.817687     0.714286
# 62       0.817687     0.714286

# %%
df_concat[df_concat["test recall"] == 4/7].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#      class_weight_YN  null_del  encoded scaler   sampler    classifier  \
# 140                1       1.0      1.0     SD  SVMSMOTE   LogisticReg
# 73                 1       0.0      0.0     SD  BdlSMOTE      LightGBM
# 2                  1       1.0      1.0   None  BdlSMOTE  RandomForest
#
#      test accuracy  test recall
# 140       0.745274     0.571429
# 73        0.715796     0.571429
# 2         0.700096     0.571429

# %%
df_concat[df_concat["test recall"] == 3/7].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#     class_weight_YN  null_del  encoded scaler            sampler classifier  \
# 8                 0       0.0      0.0   None  RandomOverSampler   LightGBM
# 18                0       0.0      0.0     MM  RandomOverSampler   LightGBM
# 28                0       0.0      0.0     SD  RandomOverSampler   LightGBM
#
#     test accuracy  test recall
# 8        0.830503     0.428571
# 18       0.830503     0.428571
# 28       0.830503     0.428571

# %%
df_concat[df_concat["test recall"] == 2/7].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#     class_weight_YN  null_del  encoded scaler   sampler classifier  \
# 63                0       0.0      0.0   None  BdlSMOTE   LightGBM
# 68                0       0.0      0.0     MM  BdlSMOTE   LightGBM
# 73                0       0.0      0.0     SD  BdlSMOTE   LightGBM
#
#     test accuracy  test recall
# 63       0.960269     0.285714
# 68       0.960269     0.285714
# 73       0.960269     0.285714

# %%
df_concat[df_concat["test recall"] == 1/7].head(3)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
# Out:
#     class_weight_YN  null_del  encoded scaler   sampler classifier  \
# 34                0       1.0      0.0     SD  BdlSMOTE        SVC
# 3                 0       0.0      0.0   None  SVMSMOTE   LightGBM
# 13                0       0.0      0.0     MM  SVMSMOTE   LightGBM
#
#     test accuracy  test recall
# 34       0.981416     0.142857
# 3        0.968920     0.142857
# 13       0.968920     0.142857

# %%
best_77 = df_concat[df_concat["test recall"] == 1].head(1)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
best_67 = df_concat[df_concat["test recall"] == 6/7].head(1)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
best_57 = df_concat[df_concat["test recall"] == 5/7].head(1)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
best_47 = df_concat[df_concat["test recall"] == 4/7].head(1)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]
best_37 = df_concat[df_concat["test recall"] == 3/7].head(1)[["class_weight_YN", 'null_del', 'encoded', 'scaler', 'sampler', 'classifier', 
                                                 'test accuracy', 'test recall']]

best_concat = pd.concat([best_77, best_67, best_57, best_47, best_37], axis=0)
best_concat
# Out:
#      class_weight_YN  null_del  encoded scaler            sampler  \
# 44                 0       0.0      1.0   None           BdlSMOTE
# 0                  0       0.0      0.0   None           SVMSMOTE
# 42                 1       1.0      0.0   None           SVMSMOTE
# 140                1       1.0      1.0     SD           SVMSMOTE
# 8                  0       0.0      0.0   None  RandomOverSampler
#
#        classifier  test accuracy  test recall
# 44            SVC       0.284204     1.000000
# 0     LogisticReg       0.684396     0.857143
# 42   RandomForest       0.817687     0.714286
# 140   LogisticReg       0.745274     0.571429
# 8        LightGBM       0.830503     0.428571
