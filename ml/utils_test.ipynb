# %% [markdown]
# # utils
# - split_train_test(df) \
#     sc 데이터 프레임 변환
#
#
# - fit_sampler(X_train, y_train, sampler='SMOTE') \
#     샘플러 선택
#
#
# - ut.fit_cv(X_train_over, y_train_over, X_test, y_test) \
#     학습과 결과

# %%
import utils as ut

# %%
df = pd.read_csv('../datas/insurance_fraud_detect_data.csv')
df.shape
# Out:
# (16000, 25)

# %% [markdown]
# # Use case
# socar_preprocessing-seunghwan의 **16번째 방법**에 적용 \
# (null삭제, 원핫인코딩, smote, Robust)

# %% [markdown]
# # --1

# %% [markdown]
# ### (1) NULL 데이터 삭제, (2) 원핫인코딩 적용, (3) 데이터 분리, (4) SMOTE

# %%
# null 삭제
socar_delete = df.drop(['accident_hour', 'repair_cost', 'insure_cost', 'accident_location', 'acc_type1', 'insurance_site_aid_YN', 'police_site_aid_YN', 'total_prsn_cnt'], axis=1)
# 1hot
cat_attribs = socar_delete.columns.drop(['fraud_YN', 'accident_ratio', 'repair_cnt', 'test_set'])
socar_df = pd.get_dummies(socar_delete, columns=cat_attribs)
# 데이터 분리
X_train, X_test, y_train, y_test = ut.split_train_test(socar_df)
# sampling to SMOTE (default)
X_train_over, y_train_over = ut.fit_sampler(X_train, y_train, sampler='SMOTE')
# Out:
# ==Split Result==
# y_train :  [[0, 1], [12845, 34]]
# y_test : [[0, 1], [3114, 7]]
# ==Sampling Result==
# y_train :  [[0, 1], [12845, 34]]
# y_train_over : [[0, 1], [12845, 12845]]

# %% [markdown]
# ### (5) RobustScaler, (6) 학습 (scoring = 'recall')

# %%
import utils as ut


ut.fit_cv(X_train_over, y_train_over, X_test, y_test, scaler='RB', scoring='recall')
# Out:
# => confusion matrix
# [[12845     0]
#  [   34 12811]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.998677        1.0  0.997353  0.998675  0.998677
# ======================
# => confusion matrix
# [[3114    0]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1  roc_auc
# 0  0.997757        0.0     0.0  0.0      0.5
# ======================
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# => confusion matrix
# [[12845     0]
#  [   12 12833]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.999533        1.0  0.999066  0.999533  0.999533
# ======================
# => confusion matrix
# [[3103   11]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1   roc_auc
# 0  0.994233        0.0     0.0  0.0  0.498234
# ======================
# => confusion matrix
# [[12381   464]
#  [   89 12756]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.978474   0.964902  0.993071  0.978784  0.978474
# ======================
# => confusion matrix
# [[2995  119]
#  [   6    1]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.959949   0.008333  0.142857  0.015748  0.552321
# ======================
# => confusion matrix
# [[12796    49]
#  [   30 12815]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.996925   0.996191  0.997664  0.996927  0.996925
# ======================
# => confusion matrix
# [[3104   10]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1   roc_auc
# 0  0.994553        0.0     0.0  0.0  0.498394
# ======================
# => confusion matrix
# [[ 1624 11221]
#  [    1 12844]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.563176   0.533721  0.999922  0.695963  0.563176
# ======================
# => confusion matrix
# [[ 391 2723]
#  [   1    6]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.127203   0.002199  0.857143  0.004386  0.491352
# ======================
# Fit time : 233.88258481025696
#      classifier  train accuracy  train precision  train recall  train f1  \
# 0   LogisticReg        0.998677         1.000000      0.997353  0.998675
# 1  DecisionTree        0.999533         1.000000      0.999066  0.999533
# 2  RandomForest        0.978474         0.964902      0.993071  0.978784
# 3      LightGBM        0.996925         0.996191      0.997664  0.996927
# 4           SVC        0.563176         0.533721      0.999922  0.695963
#
#    train auc  test accuracy  test precision  test recall   test f1  test auc
# 0   0.998677       0.997757        0.000000     0.000000  0.000000  0.500000
# 1   0.999533       0.994233        0.000000     0.000000  0.000000  0.498234
# 2   0.978474       0.959949        0.008333     0.142857  0.015748  0.552321
# 3   0.996925       0.994553        0.000000     0.000000  0.000000  0.498394
# 4   0.563176       0.127203        0.002199     0.857143  0.004386  0.491352

# %% [markdown]
# # --2

# %% [markdown]
# ### 같은 케이스로 parameter에 c 값을 넣어서 cv 해봄
# 큰 차이가 없다

# %%
ut.fit_cv(X_train_over, y_train_over, X_test, y_test, scaler='RB', scoring='f1')
# Out:
# => confusion matrix
# [[12845     0]
#  [   34 12811]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.998677        1.0  0.997353  0.998675  0.998677
# ====Done Evaluation====
# => confusion matrix
# [[3114    0]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1  roc_auc
# 0  0.997757        0.0     0.0  0.0      0.5
# ====Done Evaluation====
# ##
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# => confusion matrix
# [[12845     0]
#  [   12 12833]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.999533        1.0  0.999066  0.999533  0.999533
# ====Done Evaluation====
# => confusion matrix
# [[3103   11]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1   roc_auc
# 0  0.994233        0.0     0.0  0.0  0.498234
# ====Done Evaluation====
# ##=> confusion matrix
# [[12843     2]
#  [   13 12832]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.999416   0.999844  0.998988  0.999416  0.999416
# ====Done Evaluation====
# => confusion matrix
# [[3111    3]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1   roc_auc
# 0  0.996796        0.0     0.0  0.0  0.499518
# ====Done Evaluation====
# ##=> confusion matrix
# [[12845     0]
#  [   34 12811]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.998677        1.0  0.997353  0.998675  0.998677
# ====Done Evaluation====
# => confusion matrix
# [[3114    0]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1  roc_auc
# 0  0.997757        0.0     0.0  0.0      0.5
# ====Done Evaluation====
# ##
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# => confusion matrix
# [[12845     0]
#  [   33 12812]]
# ======================
#    accuracy  precision    recall        f1   roc_auc
# 0  0.998715        1.0  0.997431  0.998714  0.998715
# ====Done Evaluation====
# => confusion matrix
# [[3114    0]
#  [   7    0]]
# ======================
#    accuracy  precision  recall   f1  roc_auc
# 0  0.997757        0.0     0.0  0.0      0.5
# ====Done Evaluation====
# ##Fit time : 826.2700021266937
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#      classifier  train accuracy  train precision  train recall  train f1  \
# 0   LogisticReg        0.998677         1.000000      0.997353  0.998675
# 1  DecisionTree        0.999533         1.000000      0.999066  0.999533
# 2  RandomForest        0.999416         0.999844      0.998988  0.999416
# 3      LightGBM        0.998677         1.000000      0.997353  0.998675
# 4           SVC        0.998715         1.000000      0.997431  0.998714
#
#    train auc  test accuracy  test precision  test recall  test f1  test auc
# 0   0.998677       0.997757             0.0          0.0      0.0  0.500000
# 1   0.999533       0.994233             0.0          0.0      0.0  0.498234
# 2   0.999416       0.996796             0.0          0.0      0.0  0.499518
# 3   0.998677       0.997757             0.0          0.0      0.0  0.500000
# 4   0.998715       0.997757             0.0          0.0      0.0  0.500000

# %% [markdown]
# # --3

# %% [markdown]
# ### 같은 케이스로 borderlineSMOTE 사용

# %% [markdown]
# ### (1) NULL 데이터 삭제, (2) 원핫인코딩 적용, (3) 데이터 분리, (4) BorderlineSMOTE

# %%
# null 삭제
socar_delete = df.drop(['accident_hour', 'repair_cost', 'insure_cost', 'accident_location', 'acc_type1', 'insurance_site_aid_YN', 'police_site_aid_YN', 'total_prsn_cnt'], axis=1)
# 1hot
cat_attribs = socar_delete.columns.drop(['fraud_YN', 'accident_ratio', 'repair_cnt', 'test_set'])
socar_df = pd.get_dummies(socar_delete, columns=cat_attribs)
# 데이터 분리
X_train, X_test, y_train, y_test = ut.split_train_test(socar_df)
# sampling to SMOTE (default)
X_train_over, y_train_over = ut.fit_sampler(X_train, y_train, sampler='BorderlineSMOTE')
# Out:
# ==Split Result==
# y_train :  [[0, 1], [12845, 34]]
# y_test : [[0, 1], [3114, 7]]
# ==Sampling Result==
# y_train :  [[0, 1], [12845, 34]]
# y_train_over : [[0, 1], [12845, 12845]]

# %%
# matrix와 점수 안보겠습니다
ut.fit_cv(X_train_over, y_train_over, X_test, y_test, scaler='RB', scoring='recall', conf_m=False, view_scores=False)
# Out:
# ====Done Evaluation====
# ====Done Evaluation====
# ##
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ====Done Evaluation====
# ====Done Evaluation====
# ##====Done Evaluation====
# ====Done Evaluation====
# ##====Done Evaluation====
# ====Done Evaluation====
# ##====Done Evaluation====
# ====Done Evaluation====
# ##Fit time : 551.0
#      classifier  train accuracy  train precision  train recall  train f1  \
# 0   LogisticReg        0.998677         1.000000      0.997353  0.998675
# 1  DecisionTree        0.813896         0.729065      0.999066  0.842973
# 2  RandomForest        0.725496         0.645707      0.999299  0.784501
# 3      LightGBM        0.904321         0.840267      0.998443  0.912552
# 4           SVC        0.564928         0.534721      0.999922  0.696813
#
#    train auc  test accuracy  test precision  test recall   test f1  test auc
# 0   0.998677       0.997757        0.000000     0.000000  0.000000  0.500000
# 1   0.813896       0.442807        0.003440     0.857143  0.006853  0.649509
# 2   0.725496       0.204422        0.002811     1.000000  0.005607  0.601317
# 3   0.904321       0.759052        0.005312     0.571429  0.010526  0.665451
# 4   0.564928       0.129766        0.002205     0.857143  0.004399  0.492637

# %% [markdown]
# # --4
# ### ADASYN 사용

# %% [markdown]
# ### (1) NULL 데이터 삭제, (2) 원핫인코딩 적용, (3) 데이터 분리, (4) ADASYN

# %%
# null 삭제
socar_delete = df.drop(['accident_hour', 'repair_cost', 'insure_cost', 'accident_location', 'acc_type1', 'insurance_site_aid_YN', 'police_site_aid_YN', 'total_prsn_cnt'], axis=1)
# 1hot
cat_attribs = socar_delete.columns.drop(['fraud_YN', 'accident_ratio', 'repair_cnt', 'test_set'])
socar_df = pd.get_dummies(socar_delete, columns=cat_attribs)
# 데이터 분리
X_train, X_test, y_train, y_test = ut.split_train_test(socar_df)
# sampling to SMOTE (default)
X_train_over, y_train_over = ut.fit_sampler(X_train, y_train, sampler='ADASYN')
# Out:
# ==Split Result==
# y_train :  [[0, 1], [12845, 34]]
# y_test : [[0, 1], [3114, 7]]
# ==Sampling Result==
# y_train :  [[0, 1], [12845, 34]]
# y_train_over : [[0, 1], [12845, 12841]]

# %%
cv_list = ut.fit_cv(X_train_over, y_train_over, X_test, y_test, scaler='RB', scoring='recall', conf_m=False, view_scores=False)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ....................................clf__penalty=l2; total time=   0.2s
# [CV] END ....................................clf__penalty=l2; total time=   0.2s
# [CV] END ....................................clf__penalty=l2; total time=   0.2s
# [CV] END ....................................clf__penalty=l2; total time=   0.2s
# [CV] END ....................................clf__penalty=l2; total time=   0.2s
# ====Done Evaluation====
# ====Done Evaluation====
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ................................clf__max_depth=None; total time=   0.1s
# [CV] END ................................clf__max_depth=None; total time=   0.1s
# [CV] END ................................clf__max_depth=None; total time=   0.1s
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END ................................clf__max_depth=None; total time=   0.1s
# [CV] END ................................clf__max_depth=None; total time=   0.1s
# [CV] END ...................................clf__max_depth=2; total time=   0.0s
# [CV] END ...................................clf__max_depth=2; total time=   0.0s
# [CV] END ...................................clf__max_depth=2; total time=   0.0s
# [CV] END ...................................clf__max_depth=2; total time=   0.0s
# [CV] END ...................................clf__max_depth=2; total time=   0.0s
# [CV] END ...................................clf__max_depth=3; total time=   0.0s
# [CV] END ...................................clf__max_depth=3; total time=   0.0s
# [CV] END ...................................clf__max_depth=3; total time=   0.0s
# [CV] END ...................................clf__max_depth=3; total time=   0.0s
# [CV] END ...................................clf__max_depth=3; total time=   0.0s
# [CV] END ...................................clf__max_depth=4; total time=   0.0s
# [CV] END ...................................clf__max_depth=4; total time=   0.0s
# [CV] END ...................................clf__max_depth=4; total time=   0.0s
# [CV] END ...................................clf__max_depth=4; total time=   0.0s
# [CV] END ...................................clf__max_depth=4; total time=   0.0s
# ====Done Evaluation====
# ====Done Evaluation====
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# ====Done Evaluation====
# ====Done Evaluation====
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   0.1s
# ====Done Evaluation====
# ====Done Evaluation====
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# /Users/dockyum/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.9s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  29.3s
# ====Done Evaluation====
# ====Done Evaluation====
# Fit time : 3.04 min

# %% [markdown]
# ### cv_list 를 return 값으로 줘서 활용 가능하게 만들자

# %%
cv_list[3]
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', RobustScaler()),
#                                        ('clf',
#                                         LGBMClassifier(boost_from_average=False,
#                                                        random_state=13))],
#                                 verbose=True),
#              param_grid=[{'clf__n_estimators': [10, 30, 50, 100],
#                           'clf__num_leaves': [4, 8, 16]}],
#              scoring='recall')
